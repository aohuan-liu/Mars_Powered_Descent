# %%
import Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
import FiniteDiff
import ForwardDiff as FD
import Convex as cvx 
import ECOS
using LinearAlgebra
using Plots
using Random
using JLD2
using Test
using MeshCat
const mc = MeshCat
using StaticArrays
using Printf
# Out:
#   Activating project at `c:\Users\17978\Desktop\cmu 16-745\2.code\HW\HW4`
# Precompiling packages...
#     Unitful Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Unitful\5WYj5_BOA4w.ji.pidfile)
#     FileIO Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\FileIO\6iKRU_BOA4w.ji.pidfile)
#     MutableArithmetics Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\MutableArithmetics\EoEec_BOA4w.ji.pidfile)
#     Parsers Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Parsers\833b9_BOA4w.ji.pidfile)
#    1248.0 ms  ✓ Adapt
#     DiffResults Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\DiffResults\vlfPe_BOA4w.ji.pidfile)
#    1361.5 ms  ✓ LoggingExtras
#    1314.3 ms  ✓ Quaternions
#    1424.0 ms  ✓ ConstructionBase
#    1942.8 ms  ✓ Compat → CompatLinearAlgebraExt
#     688.9 ms  ✓ Libmount_jll
#     706.3 ms  ✓ Graphite2_jll
#    2249.6 ms  ✓ Parameters
#     817.4 ms  ✓ OpenSSL_jll
#     986.5 ms  ✓ DiffResults
#    2362.2 ms  ✓ RecipesBase
#     902.9 ms  ✓ EpollShim_jll
#    3175.9 ms  ✓ MacroTools
#    2918.2 ms  ✓ RelocatableFolders
#    1033.3 ms  ✓ LLVMOpenMP_jll
#    1203.1 ms  ✓ Bzip2_jll
#    1142.8 ms  ✓ Xorg_libICE_jll
#    1133.0 ms  ✓ Xorg_libXau_jll
#    1282.4 ms  ✓ METIS_jll
#    1413.0 ms  ✓ libpng_jll
#    1111.1 ms  ✓ libfdk_aac_jll
#    4054.9 ms  ✓ LogExpFunctions
#    4009.9 ms  ✓ GeoInterface
#    1166.4 ms  ✓ ASL_jll
#    1121.6 ms  ✓ LAME_jll
#    1189.8 ms  ✓ Hwloc_jll
#    1206.2 ms  ✓ LERC_jll
#    1180.7 ms  ✓ EarCut_jll
#    1198.7 ms  ✓ fzf_jll
#    1230.6 ms  ✓ JpegTurbo_jll
#    1151.5 ms  ✓ Ogg_jll
#    1075.3 ms  ✓ mtdev_jll
#    1181.3 ms  ✓ XZ_jll
#     992.7 ms  ✓ Xorg_libXdmcp_jll
#    1174.5 ms  ✓ gperf_jll
#    1154.6 ms  ✓ x264_jll
#    1167.9 ms  ✓ x265_jll
#    1203.2 ms  ✓ Expat_jll
#    1223.8 ms  ✓ Zstd_jll
#    1238.5 ms  ✓ libaom_jll
#    1267.9 ms  ✓ LZO_jll
#    1015.7 ms  ✓ libevdev_jll
#    1134.4 ms  ✓ Opus_jll
#    1074.5 ms  ✓ Xorg_xtrans_jll
#    1207.2 ms  ✓ ECOS_jll
#    1195.7 ms  ✓ Libffi_jll
#    1258.0 ms  ✓ Libiconv_jll
#    1230.6 ms  ✓ Libgpg_error_jll
#     DataStructures Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\DataStructures\xKiwJ_BOA4w.ji.pidfile)
#    1019.3 ms  ✓ Wayland_protocols_jll
#    1050.1 ms  ✓ Xorg_libpthread_stubs_jll
#    1240.1 ms  ✓ OpenSpecFun_jll
#    1089.2 ms  ✓ Libuuid_jll
#    1121.2 ms  ✓ FriBidi_jll
#    1105.6 ms  ✓ OpenBLAS32_jll
#    1553.5 ms  ✓ ArrayInterface
#    1397.0 ms  ✓ Pixman_jll
#    1819.1 ms  ✓ Adapt → AdaptSparseArraysExt
#    1587.8 ms  ✓ CommonSubexpressions
#    1799.5 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    1470.0 ms  ✓ CodecBzip2
#    1482.8 ms  ✓ FreeType2_jll
#     911.7 ms  ✓ Xorg_libSM_jll
#     Libtiff_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Libtiff_jll\f0w9B_BOA4w.ji.pidfile)
#    2843.5 ms  ✓ ColorTypes
#     XML2_jll Being precompiled by another process (pid: 55536, pidfile: C:\Users\17978\.julia\compiled\v1.10\XML2_jll\xWVg2_BOA4w.ji.pidfile)
#    9650.1 ms  ✓ MutableArithmetics
#     914.4 ms  ✓ Dbus_jll
#     970.2 ms  ✓ eudev_jll
#    9951.9 ms  ✓ FileIO
#    1463.5 ms  ✓ JLFzf
#     SpecialFunctions Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\SpecialFunctions\78gOt_BOA4w.ji.pidfile)
#    1808.3 ms  ✓ libvorbis_jll
#     Fontconfig_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Fontconfig_jll\xsKJT_BOA4w.ji.pidfile)
#     197.7 ms  ✓ Fontconfig_jll
#    1296.8 ms  ✓ XML2_jll
#     Colors Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Colors\NKjaT_BOA4w.ji.pidfile)
#    2136.9 ms  ✓ MUMPS_seq_jll
#     969.7 ms  ✓ Libgcrypt_jll
#     JLD2 Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\JLD2\O1EyT_BOA4w.ji.pidfile)
#    4101.4 ms  ✓ DataStructures
#     355.5 ms  ✓ Colors
#     938.3 ms  ✓ SpecialFunctions
#     Gettext_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Gettext_jll\l4zGN_BOA4w.ji.pidfile)
#     XSLT_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\XSLT_jll\HNSqD_BOA4w.ji.pidfile)
#    3996.6 ms  ✓ Latexify
#    1353.1 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#     DiffRules Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\DiffRules\x2ZNk_BOA4w.ji.pidfile)
#     857.8 ms  ✓ libinput_jll
#   11413.7 ms  ✓ StaticArrays
#    1503.4 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#     872.2 ms  ✓ Wayland_jll
#    3172.5 ms  ✓ SPRAL_jll
#    4990.0 ms  ✓ OpenSSL
#     946.2 ms  ✓ DiffRules
#    2158.5 ms  ✓ SortingAlgorithms
#    4068.6 ms  ✓ Libtiff_jll
#     HTTP Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\HTTP\zXWya_BOA4w.ji.pidfile)
#    3441.5 ms  ✓ Setfield
#     ForwardDiff Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\ForwardDiff\k0ETY_BOA4w.ji.pidfile)
#    2032.3 ms  ✓ Latexify → SparseArraysExt
#    2001.4 ms  ✓ Adapt → AdaptStaticArraysExt
#     StatsBase Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\StatsBase\EZjIG_BOA4w.ji.pidfile)
#    2141.3 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    2048.3 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    2365.2 ms  ✓ CoordinateTransformations
#   14042.3 ms  ✓ Parsers
#    3519.2 ms  ✓ XSLT_jll
#    3530.7 ms  ✓ Gettext_jll
#    3911.9 ms  ✓ ColorVectorSpace
#     Glib_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Glib_jll\S5dsb_BOA4w.ji.pidfile)
#     ColorSchemes Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\ColorSchemes\EO5fj_BOA4w.ji.pidfile)
#    1926.7 ms  ✓ FiniteDiff
#    1309.5 ms  ✓ Xorg_libxcb_jll
#    4065.9 ms  ✓ Rotations
#   16091.6 ms  ✓ Unitful
#     901.1 ms  ✓ Xorg_xcb_util_jll
#     921.7 ms  ✓ Xorg_libX11_jll
#    2300.4 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#     UnitfulLatexify Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\UnitfulLatexify\trCzg_BOA4w.ji.pidfile)
#    3053.6 ms  ✓ JSON
#    1543.1 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#     691.4 ms  ✓ Xorg_xcb_util_image_jll
#    3187.6 ms  ✓ Glib_jll
#    1610.7 ms  ✓ Rotations → RotationsRecipesBaseExt
#     724.5 ms  ✓ Xorg_xcb_util_keysyms_jll
#     777.6 ms  ✓ Xorg_xcb_util_renderutil_jll
#    2483.5 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#     865.7 ms  ✓ Xorg_xcb_util_wm_jll
#    4664.5 ms  ✓ StatsBase
#     BenchmarkTools Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\BenchmarkTools\ZXPQo_BOA4w.ji.pidfile)
#    1723.6 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#     891.7 ms  ✓ Xorg_libXrender_jll
#     881.9 ms  ✓ Xorg_libXext_jll
#     Cairo_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Cairo_jll\ouRHo_BOA4w.ji.pidfile)
#     765.4 ms  ✓ Xorg_libXfixes_jll
#     739.9 ms  ✓ Xorg_libxkbfile_jll
#    5491.7 ms  ✓ ForwardDiff
#     739.7 ms  ✓ Xorg_xcb_util_cursor_jll
#     749.6 ms  ✓ Xorg_libXinerama_jll
#     804.2 ms  ✓ Xorg_libXrandr_jll
#     884.7 ms  ✓ Libglvnd_jll
#     802.0 ms  ✓ Xorg_libXcursor_jll
#     781.4 ms  ✓ Xorg_libXi_jll
#     774.6 ms  ✓ Xorg_xkbcomp_jll
#    1958.5 ms  ✓ BenchmarkTools
#    1535.1 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    6286.1 ms  ✓ ColorSchemes
#     PlotUtils Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\PlotUtils\YveHG_BOA4w.ji.pidfile)
#    1302.4 ms  ✓ Xorg_xkeyboard_config_jll
#    4628.4 ms  ✓ UnitfulLatexify
#     538.1 ms  ✓ xkbcommon_jll
#     611.5 ms  ✓ Vulkan_Loader_jll
#     Qt6Base_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Qt6Base_jll\Lg7vK_BOA4w.ji.pidfile)
#    8208.1 ms  ✓ JSON3
#   11804.5 ms  ✓ GeometryBasics
#   13704.3 ms  ✓ Ipopt_jll
#   10334.6 ms  ✓ Cairo_jll
#     HarfBuzz_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\HarfBuzz_jll\h60co_BOA4w.ji.pidfile)
#    7993.1 ms  ✓ Qt6Base_jll
#     Qt6ShaderTools_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Qt6ShaderTools_jll\O8E7A_BOA4w.ji.pidfile)
#   11201.6 ms  ✓ PlotUtils
#   20256.8 ms  ✓ HTTP
#    5205.8 ms  ✓ HarfBuzz_jll
#     libass_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\libass_jll\JqZi8_BOA4w.ji.pidfile)
#     Pango_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Pango_jll\lZI8Y_BOA4w.ji.pidfile)
#    3291.3 ms  ✓ PlotThemes
#    1277.0 ms  ✓ Pango_jll
#    1956.5 ms  ✓ FileIO → HTTPExt
#    3594.2 ms  ✓ RecipesPipeline
#     472.2 ms  ✓ libdecor_jll
#     453.4 ms  ✓ GLFW_jll
#   12166.6 ms  ✓ Qt6ShaderTools_jll
#     Qt6Declarative_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Qt6Declarative_jll\rB4FL_BOA4w.ji.pidfile)
#    9076.7 ms  ✓ libass_jll
#     FFMPEG_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\FFMPEG_jll\uSD0T_BOA4w.ji.pidfile)
#    5045.5 ms  ✓ Qt6Declarative_jll
#   25109.7 ms  ✓ MathOptInterface
#   36808.5 ms  ✓ JLD2
#     444.9 ms  ✓ Qt6Wayland_jll
#    3043.4 ms  ✓ ECOS
#    4803.0 ms  ✓ Convex
#   10562.6 ms  ✓ FFMPEG_jll
#     FFMPEG Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\FFMPEG\TGvga_BOA4w.ji.pidfile)
#     GR_jll Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\GR_jll\jV9xf_BOA4w.ji.pidfile)
#    8136.6 ms  ✓ Ipopt
#    4967.3 ms  ✓ FFMPEG
#     MeshCat Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\MeshCat\CZdjb_BOA4w.ji.pidfile)
#   11675.7 ms  ✓ GR_jll
#     GR Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\GR\NDU5Y_BOA4w.ji.pidfile)
#    3512.6 ms  ✓ GR
#     Plots Being precompiled by another process (pid: 22952, pidfile: C:\Users\17978\.julia\compiled\v1.10\Plots\ld3vC_BOA4w.ji.pidfile)
#   11919.3 ms  ✓ MeshCat
#   68730.3 ms  ✓ Plots
#    5075.3 ms  ✓ Plots → UnitfulExt
#    1745.6 ms  ✓ Plots → FileIOExt
#    2043.4 ms  ✓ Plots → GeometryBasicsExt
#   166 dependencies successfully precompiled in 148 seconds. 57 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MeshCat
# │  [ Info: Listening on: 127.0.0.1:8700, thread id: 1
# │  ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │  └ http://127.0.0.1:8700
# │  [ Info: Server on 127.0.0.1:8700 closing
# │  [ Info: MeshCat server closed.
# └
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]

# %%
include(joinpath(@__DIR__, "utils","ilc_visualizer.jl"))
# Out:
# update_car_pose! (generic function with 1 method)

# %% [markdown]
# # Q1: Iterative Learning Control (ILC) (40 pts)
#
# In this problem, you will use ILC to generate a control trajectory for a Car as it swerves to avoid a moose, also known as "the moose test" ([wikipedia](https://en.wikipedia.org/wiki/Moose_test), [video](https://www.youtube.com/watch?v=TZ2MYFInpMI)). We will model the dynamics of the car as with a simple nonlinear bicycle model, with the following state and control:
#
# $$\begin{align} x = \begin{bmatrix} p_x \\ p_y \\ \theta \\ \delta \\ v  \end{bmatrix}, &\quad \quad u = \begin{bmatrix} a \\ \dot{\delta} \end{bmatrix}  \end{align} $$
#
# where $p_x$ and $p_y$ describe the 2d position of the bike, $\theta$ is the orientation, $\delta$ is the steering angle, and $v$ is the velocity. The controls for the bike are acceleration $a$, and steering angle rate $\dot{\delta}$.

# %%
function estimated_car_dynamics(model::NamedTuple, x::Vector, u::Vector)::Vector
    # nonlinear bicycle model continuous time dynamics 
    px, py, θ, δ, v = x 
    a, δdot = u 
    
    β = atan(model.lr * δ, model.L)
    s,c = sincos(θ + β)
    ω = v*cos(β)*tan(δ) / model.L
    
    vx = v*c 
    vy = v*s 
    
    xdot = [
        vx,
        vy,
        ω,
        δdot, 
        a
    ]
    
    return xdot 
end
function rk4(model::NamedTuple, ode::Function, x::Vector, u::Vector, dt::Real)::Vector
    k1 = dt * ode(model, x,        u)
    k2 = dt * ode(model, x + k1/2, u)
    k3 = dt * ode(model, x + k2/2, u)
    k4 = dt * ode(model, x + k3,   u)
    return x + (1/6)*(k1 + 2*k2 + 2*k3 + k4)
end
# Out:
# rk4 (generic function with 1 method)

# %% [markdown]
# We have computed an optimal trajectory $X_{ref}$ and $U_{ref}$ for a moose test trajectory offline using this `estimated_car_dynamics` function. Unfortunately, this is a highly approximate dynamics model, and when we run $U_{ref}$ on the car, we get a very different trajectory than we expect. This is caused by a significant sim to real gap. Here we will show what happens when we run these controls on the true dynamics:

# %%
function load_car_trajectory()
    # load in trajectory we computed offline 
    path = joinpath(@__DIR__, "utils","init_control_car_ilc.jld2")
    F = jldopen(path)
    Xref = F["X"]
    Uref = F["U"]
    close(F)
    return Xref, Uref
end
function true_car_dynamics(model::NamedTuple, x::Vector, u::Vector)::Vector
    # true car dynamics 
    px, py, θ, δ, v = x 
    a, δdot = u 
    
    # sluggish controls (not in the approximate version)
    a = 0.9*a - 0.1 
    δdot = 0.9*δdot - .1*δ + .1
    
    β = atan(model.lr * δ, model.L)
    s,c = sincos(θ + β)
    ω = v*cos(β)*tan(δ) / model.L
    
    vx = v*c 
    vy = v*s 
    
    xdot = [
        vx,
        vy,
        ω,
        δdot, 
        a
    ]
    
    return xdot 
end

@testset "sim to real gap" begin 
    # problem size 
    nx = 5
    nu = 2
    dt = 0.1
    tf = 5.0 
    t_vec = 0:dt:tf 
    N = length(t_vec)
    model = (L = 2.8, lr = 1.6)
    
    # optimal trajectory computed offline with approximate model 
    Xref, Uref = load_car_trajectory()
    
    # TODO: simulated Uref with the true car dynamics and store the states in Xsim
    Xsim = [zeros(nx) for i = 1:N]

    
    # --------testing------------------
    @test norm(Xsim[1] - Xref[1]) == 0 
    @test norm(Xsim[end] - [3.26801052, 15.0590156, 2.0482790, 0.39056168, 4.5],Inf) < 1e-4
    
    # --------plotting/animation-------
    Xm= hcat(Xsim...)
    Xrefm = hcat(Xref...)
    plot(Xrefm[1,:], Xrefm[2,:], ls = :dash, label = "reference",
         xlabel = "x (m)", ylabel = "y (m)", title = "Simulation vs Reference")
    display(plot!(Xm[1,:], Xm[2,:], label = "actual"))
    
end
# Out:
# sim to real gap: Test Failed at In[9]:55
#   Expression: norm(Xsim[1] - Xref[1]) == 0
#    Evaluated: 13.46291201783626 == 0
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:672 [inlined]
#  [2] macro expansion
#    @ In[9]:55 [inlined]
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1577 [inlined]
#  [4] top-level scope
#    @ In[9]:39
# sim to real gap: Test Failed at In[9]:56
#   Expression: norm(Xsim[end] - [3.26801052, 15.0590156, 2.048279, 0.39056168, 4.5], Inf) < 0.0001
#    Evaluated: 15.0590156 < 0.0001
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:672 [inlined]
#  [2] macro expansion
#    @ In[9]:56 [inlined]
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1577 [inlined]
#  [4] top-level scope
#    @ In[9]:39
# Test Summary:   | Fail  Total  Time
# sim to real gap |    2      2  0.1s
# Some tests did not pass: 0 passed, 2 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet; print_results::Bool)
#    @ Test C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1195
#  [2] finish(ts::Test.DefaultTestSet)
#    @ Test C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1170
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1593 [inlined]
#  [4] top-level scope
#    @ In[9]:39

# %% [markdown]
# In order to account for this, we are going to use ILC to iteratively correct our control until we converge.
#
# To encourage the trajectory of the bike to follow the reference, the objective value for this problem is the following:
# $$  J(X,U) = \sum_{i=1}^{N-1} \bigg[ \frac{1}{2} (x_i - x_{ref,i})^TQ(x_i - x_{ref,i}) + \frac{1}{2} (u_i-u_{ref,i})^TR(u_i-u_{ref,i}) \bigg] + \frac{1}{2}(x_N - x_{ref,N})^TQ_f(x_N - x_{ref,N})$$
#
# Using ILC as described in [Lecture 18](https://github.com/Optimal-Control-16-745/lecture-notebooks/blob/main/Lecture%2018/Lecture%2018.pdf), we are to linearize our approximate dynamics model about $X_{ref}$ and $U_{ref}$ to get the following Jacobians:
#
# $$ A_k = \frac{\partial f}{\partial x}\bigg|_{x_{ref,k},u_{ref,k}}, \quad \quad B_k = \frac{\partial f}{\partial u}\bigg|_{x_{ref,k},u_{ref,k}} $$
#
# where $f(x,u)$ is our **approximate discrete** dynamics model (`estimated_car_dynamics` + `rk4`). **You will form these Jacobians exactly once, using `Xref` and `Uref`.**  Here is a summary of the notation:
#
# - $X_{ref}$ (`Xref`) -  Optimal trajectory computed offline with approximate dynamics model.
# - $U_{ref}$ (`Uref`) -  Optimal controls computed offline with approximate dynamics model.
# - $X_{sim}$ (`Xsim`) -  Simulated trajectory with real dynamics model.
# - $\bar{U}$ (`Ubar`) -  Control we use for simulation with real dynamics model (this is what ILC updates).
#
#
# In the second step of ILC, we solve the following optimization problem:
#
#    $$ \begin{align} \min_{\Delta x_{1:N},\Delta u_{1:N-1}} \quad & J(X_{sim} + \Delta X, \bar{U} + \Delta U)\\
#  \text{st} \quad & \Delta x_1 = 0 \\
#  & \Delta x_{k+1} = A_k \Delta x_k + B_k \Delta u_k \quad \text{for } k = 1,2,\ldots,N-1 \\
#  \end{align}$$
#
# We are going to initialize our $\bar{U}$ with $U_{ref}$, then the ILC algorithm will update $\bar{U} = \bar{U} + \Delta U$ at each iteration. It should only take 5-10 iterations to converge down to $\|\Delta U\| < 1 \cdot 10^{-2}$. You do not need to do any sort of linesearch between ILC updates.

# %%
# feel free to use/not use any of these 

function trajectory_cost(Xsim::Vector{Vector{Float64}}, # simulated states 
                         Ubar::Vector{Vector{Float64}}, # simulated controls (ILC iterates this)
                         Xref::Vector{Vector{Float64}}, # reference X's we want to track
                         Uref::Vector{Vector{Float64}}, # reference U's we want to track 
                         Q::Matrix,                     # LQR tracking cost term 
                         R::Matrix,                     # LQR tracking cost term
                         Qf::Matrix                     # LQR tracking cost term
                         )::Float64                     # return cost J 
    
    J = 0 
    # TODO: return trajectory cost J(Xsim, Ubar)
end

function vec_from_mat(Xm::Matrix)::Vector{Vector{Float64}}
    # convert a matrix into a vector of vectors 
    X = [Xm[:,i] for i = 1:size(Xm,2)]
    return X 
end

function ilc_update(Xsim::Vector{Vector{Float64}}, # simulated states 
                    Ubar::Vector{Vector{Float64}}, # simulated controls (ILC iterates this)
                    Xref::Vector{Vector{Float64}}, # reference X's we want to track
                    Uref::Vector{Vector{Float64}}, # reference U's we want to track 
                    As::Vector{Matrix{Float64}},   # vector of A jacobians at each time step 
                    Bs::Vector{Matrix{Float64}},   # vector of B jacobians at each time step 
                    Q::Matrix,                     # LQR tracking cost term 
                    R::Matrix,                     # LQR tracking cost term
                    Qf::Matrix                     # LQR tracking cost term
                    )::Vector{Vector{Float64}}     # return vector of ΔU's 

    # solve optimization problem for ILC update
    N = length(Xsim)
    nx,nu = size(Bs[1])
    
    # create variables 
    ΔX = cvx.Variable(nx, N)
    ΔU = cvx.Variable(nu, N-1)

    # TODO: cost function (tracking cost on Xref, Uref)
    cost = 0.0
    cons = []
    

    # TODO: initial condition constraint

    # TODO: dynamics constraints

    # problem instance 
    prob = cvx.minimize(cost, cons)

    cvx.solve!(prob, ECOS.Optimizer; silent = true)

    # return ΔU 
    ΔU = vec_from_mat(ΔU.value)

    return ΔU
end
# Out:
# ilc_update (generic function with 1 method)

# %% [markdown]
# Here you will run your ILC algorithm. The resulting plots should show the simulated trajectory `Xsim` tracks `Xref` very closely, but there should be a significant difference between `Uref` and `Ubar`.

# %%
@testset "ILC" begin 
    
    # problem size 
    nx = 5
    nu = 2
    dt = 0.1
    tf = 5.0 
    t_vec = 0:dt:tf 
    N = length(t_vec)
    
    # optimal trajectory computed offline with approximate model 
    Xref, Uref = load_car_trajectory()
    
    # initial and terminal conditions 
    xic = Xref[1]
    xg = Xref[N]
    
    # LQR tracking cost to be used in ILC 
    Q = diagm([1,1,.1,.1,.1])
    R = .1*diagm(ones(nu))
    Qf = 1*diagm(ones(nx))
    
    # load all useful things into params 
    model = (L = 2.8, lr = 1.6)

    params = (Q = Q, R = R, Qf = Qf,xic = xic, xg = xg, Xref=Xref,Uref=Uref,
          dt = dt,
          N = N,
          model = model)    
    
    
    # this holds the sim trajectory (with real dynamics)
    Xsim = [zeros(nx) for i = 1:N]
    
    # this is the feedforward control ILC is updating 
    Ubar = [zeros(nu) for i = 1:(N-1)]
    Ubar .= Uref # initialize Ubar with Uref 
    
    # TODO: calculate Jacobians 
    
    # logging stuff 
    @printf "iter     objv        |ΔU|     \n"
    @printf "------------------------------\n"
    
    for ilc_iter = 1:10 # it should not take more than 10 iterations to converge 
        
        # TODO: rollout

        # TODO: calculate objective val (trajectory_cost) 
        obj_val = 0
        
        # solve optimization problem for update (ilc_update)
        ΔU = 0
        
        # TODO: update the control 
        
        # logging 
        @printf("%3d   %10.3e  %10.3e  \n", ilc_iter, obj_val, sum(norm.(ΔU)))
        
    end
    
    # --------plotting/animation-------
    Xm= hcat(Xsim...)
    Um = hcat(Ubar...)  
    Xrefm = hcat(Xref...)
    Urefm = hcat(Uref...) 
    plot(Xrefm[1,:], Xrefm[2,:], ls = :dash, label = "reference",
         xlabel = "x (m)", ylabel = "y (m)", title = "Trajectory")
    display(plot!(Xm[1,:], Xm[2,:], label = "actual"))
    
    plot(t_vec[1:end-1], Urefm', ls = :dash, lc = [:green :blue],label = "",
         xlabel = "time (s)", ylabel = "controls", title = "Controls (-- is reference)")
    display(plot!(t_vec[1:end-1], Um', label = ["δ̇" "a"], lc = [:green :blue]))
    
    # animation
    vis = Visualizer()
    vis_traj!(vis, :traj, [[x[1],x[2],0.1] for x in Xsim]; R = 0.02)
    build_car!(vis[:car])
    anim = mc.Animation(vis, fps=floor(Int,1/dt))
    for k = 1:N
        mc.atframe(anim, k) do
            update_car_pose!(vis[:car], Xsim[k])
        end
    end
    mc.setanimation!(vis, anim)
    display(render(vis))
    
    # ----------testing-------------
    @test 0.1 <= sum(norm.(Xsim - Xref)) <= 1.0 # should be ~0.7 
    @test 5 <=  sum(norm.(Ubar - Uref)) <= 10 # should be ~7.7
        
end
# Out:
# iter     objv        |ΔU|
# ------------------------------
#   1    0.000e+00   0.000e+00
#   2    0.000e+00   0.000e+00
#   3    0.000e+00   0.000e+00
#   4    0.000e+00   0.000e+00
#   5    0.000e+00   0.000e+00
#   6    0.000e+00   0.000e+00
#   7    0.000e+00   0.000e+00
#   8    0.000e+00   0.000e+00
#   9    0.000e+00   0.000e+00
#  10    0.000e+00   0.000e+00
# [ Info: Listening on: 127.0.0.1:8700, thread id: 1
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# └ http://127.0.0.1:8700
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), UInt8[0x83, 0xa7, 0x6f, 0x70, 0x74, 0x69, 0x6f, 0x6e, 0x73, 0x82  …  0x5f, 0x61, 0x6e, 0x69, 0x6d, 0x61, 0x74, 0x69, 0x6f, 0x6e], Dict{String, MeshCat.SceneTrees.SceneNode}("meshcat" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("traj" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("s23" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x32, 0x33], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s14" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x31, 0x34], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s18" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x31, 0x38], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s44" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x34, 0x34], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "p43" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x70, 0x34, 0x33], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s19" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x31, 0x39], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s6" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x61, 0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x36], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s11" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x31, 0x31], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "s15" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x73, 0x31, 0x35], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "p28" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x74, 0x72, 0x61, 0x6a, 0x2f, 0x70, 0x32, 0x38], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}())…)), "car" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geom" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x74, 0x2f, 0x63, 0x61, 0x72, 0x2f, 0x67, 0x65, 0x6f, 0x6d], UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x74, 0x2f, 0x63, 0x61, 0x72, 0x2f, 0x67, 0x65, 0x6f, 0x6d], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("chassis" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x6f, 0x6d, 0x2f, 0x63, 0x68, 0x61, 0x73, 0x73, 0x69, 0x73], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees ...
# ILC: Test Failed at In[8]:89
#   Expression: 0.1 <= sum(norm.(Xsim - Xref)) <= 1.0
#    Evaluated: 0.1 <= 465.8005541625015 <= 1.0
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:672 [inlined]
#  [2] macro expansion
#    @ In[8]:89 [inlined]
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1577 [inlined]
#  [4] top-level scope
#    @ In[8]:4
# ILC: Test Failed at In[8]:90
#   Expression: 5 <= sum(norm.(Ubar - Uref)) <= 10
#    Evaluated: 5 <= 0.0 <= 10
#
# Stacktrace:
#  [1] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:672 [inlined]
#  [2] macro expansion
#    @ In[8]:90 [inlined]
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1577 [inlined]
#  [4] top-level scope
#    @ In[8]:4
# Test Summary: | Fail  Total  Time
# ILC           |    2      2  5.6s
# Some tests did not pass: 0 passed, 2 failed, 0 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet; print_results::Bool)
#    @ Test C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1195
#  [2] finish(ts::Test.DefaultTestSet)
#    @ Test C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1170
#  [3] macro expansion
#    @ C:\Users\17978\.julia\juliaup\julia-1.10.10+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Test\src\Test.jl:1593 [inlined]
#  [4] top-level scope
#    @ In[8]:4
